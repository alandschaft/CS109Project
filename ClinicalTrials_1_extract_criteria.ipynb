# %% [markdown]
# # Initial setup
#
# Let's import the required libraries and set up global variables for the rest of the script.

# %%
# coding: utf-8
# !pip install tqdm
import csv
import os
import re
import shutil
import string
import zipfile
import sys
from collections import defaultdict
from lxml import objectify
import codecs
import nltk
import pandas as pd
import requests
import tarfile
import subprocess
import platform
import time
from tqdm import tqdm as progressbar # pandas df usage: 'for row in progressbar(df.itertuples(), total=df.shape[0])'
# Out:
# Requirement already satisfied (use --upgrade to upgrade): tqdm in c:\anaconda\lib\site-packages

# %% [markdown]
# Helper function to create a directory under the specified path, gracefully handling errors.

# %%
def __mkdir(*args):
    path = os.path.join(*args)
    try: 
        os.makedirs(path)
    except OSError:
        if not os.path.isdir(path):
            raise
    return path

# %%
# Create the project directory holding the downloaded data, serialized dataframes and MetaMap install.
# working_dir = __mkdir(os.path.expanduser("~"), "Medframes")

# Set working directory as the current directory of the ipython notebook
working_dir = os.getcwd()

download_dir = __mkdir(working_dir, "download", "diab")


print("Working directory: %s" % working_dir)
print("Download directory: %s" % download_dir)
# Out:
# Working directory: C:\Study\CS102\project\project2\repro2\CS109Project
# Download directory: C:\Study\CS102\project\project2\repro2\CS109Project\download\diab

# %% [markdown]
# # Data download
#
# Download CSV data from clinicaltrials.gov. The data will be written in the working directory specified above as  [data_dir]/study_fields.csv.
#
# For clinicaltrials.gov, a search term needs to be specified. In this example, we'll download search results for the term "seizure".

# %%
def download_ctgov(dest_dir, search_term):
    print("Downloading clinicaltrials.gov results for '%s' to %s" % (search_term, dest_dir))
    dl_url = "https://clinicaltrials.gov/ct2/results/download?down_stds=all&down_typ=results&down_flds=all&down_fmt=xml&term=%s&show_down=Y" % search_term

    # Download the zipped data and extract it to the output directory
    out_path = os.path.join(dest_dir, "download_ctgov.zip")
    with open(out_path, 'wb') as fh:
        r = requests.get(dl_url)
        for block in r.iter_content(1024):
            fh.write(block)
    with zipfile.ZipFile(out_path, 'r') as z:
        z.extractall(dest_dir)
    return dest_dir

# %%
download_ctgov(download_dir, "type 2 diabetes")
# Out:
# Downloading clinicaltrials.gov results for 'type 2 diabetes' to C:\Study\CS102\project\project2\repro2\CS109Project\download\diab
# 'C:\\Study\\CS102\\project\\project2\\repro2\\CS109Project\\download\\diab'

# %% [markdown]
# # Pandas import
#
# Convert the downloaded CSV data to Pandas dataframes and serialize them as Python pickles. The function reads XML files from the working directory and writes to "ctgov.pckl"

# %%
def ctgov_to_dataframe(src_dir):
    # Get all XML files in the data directory
    print("Transforming cliniclatrials download (%s) to dataframe" % (src_dir))
    data = []
    for f in [_ for _ in os.listdir(src_dir) if _.endswith('.xml')]:
        xml = objectify.parse(os.path.join(src_dir, f))
        root = xml.getroot()
        d = defaultdict(list)
        for t in root.iter():
            if t.text:
                key = re.sub(r'\[\d+\]', '', xml.getpath(t)).replace('/clinical_study/', '').replace('/', '.')
                val = t.text.strip()
                d[key].append(val)
        d = {k: v[0] if len(v) == 1 else v for k, v in d.items()}
        data.append(d)
    data_frame = pd.DataFrame(data)
    return data_frame

# %% [markdown]
# # Writing dataframes
# Transform the downloaded data to Pandas dataframes and seialize them as Python pickles.

# %%
download_dir = __mkdir(working_dir, "download", "diab")
data_dir = __mkdir(working_dir, "data", "diab")
ct_df = ctgov_to_dataframe(download_dir)
ct_df.to_pickle(os.path.join(data_dir, 'ctgov.pckl'))
# Out:
# Transforming cliniclatrials download (C:\Study\CS102\project\project2\repro2\CS109Project\download\diab) to dataframe

# %% [markdown]
# # Reading dataframes
#
# Read the pickled data back into Pandas and display the first 5 records. In this example, the pickled dataframe is serialized to "ctgov.pckl" in the working directory.

# %%
data_dir = __mkdir(working_dir, "data", "diab")
ctgov_data = pd.read_pickle(os.path.join(data_dir, 'ctgov.pckl'))
ctgov_data.head()
# Out:
#   acronym                          arm_group.arm_group_label  \
# 0  ACCORD  [Glycemia Trial: intensive control, Glycemia T...
# 1     NaN                                                NaN
# 2     NaN                                                NaN
# 3     NaN                                                NaN
# 4     NaN                                                NaN
#
#                             arm_group.arm_group_type  \
# 0  [Experimental, Active Comparator, Experimental...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                arm_group.description biospec_descr.textblock  \
# 0  [Open label administration of oral anti-hyperg...                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#   biospec_retention                            brief_summary.textblock  \
# 0               NaN  The purpose of this study is to prevent major ...
# 1               NaN  Patients with Zollinger-Ellison Syndrome suffe...
# 2               NaN  Patients with Zollinger-Ellison Syndrome suffe...
# 3               NaN  This study will examine the safety and effecti...
# 4               NaN  In patients with Zollinger-Ellison Syndrome th...
#
#                                          brief_title  \
# 0  Action to Control Cardiovascular Risk in Diabe...
# 1  Combination Chemotherapy in Patients With Zoll...
# 2  The Use of Oral Omeprazole and Intravenous Pan...
# 3  Interferon and Octreotide to Treat Zollinger-E...
# 4            Treatment of Zollinger-Ellison Syndrome
#
#   clinical_results.baseline.group_list.group.description  \
# 0  [Open label administration of oral anti-hyperg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     clinical_results.baseline.group_list.group.title     ...      \
# 0  [Glycemia Trial: Intensive Control, Glycemia T...     ...
# 1                                                NaN     ...
# 2                                                NaN     ...
# 3                                                NaN     ...
# 4                                                NaN     ...
#
#                         sponsors.collaborator.agency  \
# 0  [National Institute of Diabetes and Digestive ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   sponsors.collaborator.agency_class  \
# 0          [NIH, NIH, NIH, U.S. Fed]
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                         sponsors.lead_sponsor.agency  \
# 0  National Heart, Lung, and Blood Institute (NHLBI)
# 1  National Institute of Diabetes and Digestive a...
# 2  National Institute of Diabetes and Digestive a...
# 3  National Institute of Diabetes and Digestive a...
# 4  National Institute of Diabetes and Digestive a...
#
#   sponsors.lead_sponsor.agency_class      start_date  \
# 0                                NIH  September 1999
# 1                                NIH  September 1978
# 2                                NIH   February 1983
# 3                                NIH    October 1988
# 4                                NIH    January 1989
#
#                                         study_design      study_type  \
# 0  Allocation: Randomized, Endpoint Classificatio...  Interventional
# 1  Endpoint Classification: Safety/Efficacy Study...  Interventional
# 2                         Primary Purpose: Treatment  Interventional
# 3                         Primary Purpose: Treatment  Interventional
# 4                                                N/A   Observational
#
#   target_duration verification_date why_stopped
# 0             NaN     November 2014         NaN
# 1             NaN       August 2003         NaN
# 2             NaN     December 2007         NaN
# 3             NaN    September 2007         NaN
# 4             NaN     December 2007         NaN
#
# [5 rows x 187 columns]

# %% [markdown]
# # Extract criteria
#
# Read in the serialized data from clinicaltrials.gov and extract inclusion/exlcusion criteria, one per row. Output a Series(id_info.nct_id, Criteria, Inclusion, TokenCount).

# %%
def id_generator(first_val=0, inc_func=lambda val: val + 1):
    """
        Simple id generator. It takes first val & increase function and yields ids as needed.
        Will return integers starting from 0 by default.
    """
    id = first_val
    while True:
        yield id
        id = inc_func(id)
        

def __tokenize(text):
    # extract only alphanumerics
    tokenizer=nltk.tokenize.RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(text)
    # If first token is a number - remove it
    if len(tokens) > 0 and tokens[0].isdigit():
        tokens.pop(0)
    return tokens
        
def __process_criteria(data, get_criteria_id):
    """
        Extract inclusion and exclusion criteria from the clinical trials data.
        Then - Tokenize and write the extracted data to a frame.
    """
    pat = r"^([\w\-]*\s*){0,5}%s criteria[\s\w\(\),]*"
    inpat = re.compile(pat % 'inclusion', re.UNICODE)
    expat = re.compile(pat % 'exclusion', re.UNICODE)
    try:
        incl = True
        nct_id = data[1]
        txt = [_.strip() for _ in data[2].split(u'\n\n')]
        # Inclusion OR Exclusion
        for l in txt:
            if re.match(inpat, l.lower()):
                incl = True
                continue
            elif re.match(expat, l.lower()):
                incl = False
                continue
            else:
                toks = __tokenize(l)
                cri_id = next(get_criteria_id)
                s = {'criteria_id': cri_id, 'NctId': nct_id, 'Criteria': unicode(l), 'Include': incl, 'Tokens': toks, 'TokenCount': len(toks)}
                yield s
    except Exception as e:
        print("Error processing row %s: %s" % (data[2], e))

        
def extract_criteria(data):
    """
        Extract inclusion and exclusion criteria from each clinical trial into
    """
    print("Transforming data (extracting criteria)")
    criteria_id_generator = id_generator()
    transformed = [s for row in data[['id_info.nct_id', 'eligibility.criteria.textblock']].itertuples() for s in
                   __process_criteria(row, criteria_id_generator)]
    df = pd.DataFrame(transformed)
    return df

# %% [markdown]
# Transform the data and write the result to a file. (You'll notice that the script logs an error for one row. This is expected and results from that row being a "NaN".)

# %%
# Read in the data
data_dir = __mkdir(working_dir, "data", "diab")
ctgov_data = pd.read_pickle(os.path.join(data_dir, 'ctgov.pckl'))
# Extract criteria
criteria = extract_criteria(ctgov_data)
criteria.to_pickle(os.path.join(data_dir, 'ct_criteria.pckl'))
# Out:
# Transforming data (extracting criteria)
# Error processing row nan: 'float' object has no attribute 'split'
# Error processing row nan: 'float' object has no attribute 'split'

# %% [markdown]
# Read back the data and display a record selected by column value.

# %%
criteria = pd.read_pickle(os.path.join(data_dir, 'ct_criteria.pckl'))
criteria.loc[criteria['criteria_id'] == 5]
# Out:
#                             Criteria Include        NctId  TokenCount  \
# 5  Histologically proven gastrinoma;    True  NCT00001165           3
#
#                                  Tokens  criteria_id
# 5  [Histologically, proven, gastrinoma]            5

# %%
criteria.head(100)
# Out:
#                                              Criteria Include        NctId  \
# 0   -  Diagnosed with type 2 diabetes mellitus, as...    True  NCT00000620
# 1   -  For participants aged 40 years or older, hi...    True  NCT00000620
# 2   -  For participants aged 55 years or older, a ...    True  NCT00000620
# 3   -  HbA1c 7.5%-9% (if on more drugs) or 7.5%-11...    True  NCT00000620
# 4   Subjects selected for this study will be patie...    True  NCT00001165
# 5                   Histologically proven gastrinoma;    True  NCT00001165
# 6   Evidence of metastatic disease or locally inva...    True  NCT00001165
# 7   Progression of the tumor during the preceding ...    True  NCT00001165
# 8   The following pre-existing conditions will exc...   False  NCT00001165
# 9                           Congestive heart failure;   False  NCT00001165
# 10               Proteinuria greater than 1 gram/day;   False  NCT00001165
# 11             Serum creatinine greater than 1.5 mg%;   False  NCT00001165
# 12              Platelet count less than 100,000/mm3;   False  NCT00001165
# 13              White blood count less than 2500/mm3;   False  NCT00001165
# 14                                         Pregnancy.   False  NCT00001165
# 15  Subjects for receiving oral Omeprazole will be...    True  NCT00001191
# 16  Subjects with gastric acid hypersecretory stat...    True  NCT00001191
# 17         Patients must be 18 years of age or older.    True  NCT00001191
# 18  Female patients of childbearing age who are at...   False  NCT00001191
# 19  Patients who develop adverse reactions or alle...   False  NCT00001191
# 20  Subjects selected for this study will be patie...    True  NCT00001228
# 21               1. histologically proven gastrinoma;    True  NCT00001228
# 22  2. evidence of metastatic tumor by one or more...    True  NCT00001228
# 23  3. progression of tumor size during the preced...    True  NCT00001228
# 24             For treatment with interferon-(alpha):   False  NCT00001228
# 25                        1. Congestive heart failure   False  NCT00001228
# 26                     2. Proteinuria, 3 + or greater   False  NCT00001228
# 27        3. Creatinine clearance less than 30 ml/min   False  NCT00001228
# 28           4. Platelet count less than 30 x 10(9)/1   False  NCT00001228
# 29         5. White blood count less than 4 x 10(9)/1   False  NCT00001228
# ..                                                ...     ...          ...
# 70  4. Recent weight change of more than 3% of bod...   False  NCT00001723
# 71  5. Recent use (within six months) of anorexian...   False  NCT00001723
# 72  6. Physical impairments that would prevent com...   False  NCT00001723
# 73  Male or female patients, 18 years of age or ol...    True  NCT00001860
# 74  Newly diagnosed patients with acromegaly, or p...    True  NCT00001860
# 75  Presence of a pituitary tumor greater than 10 ...    True  NCT00001860
# 76  Lack of suppression of GH to less than 2.0 ng/...    True  NCT00001860
# 77  IGF-1 levels above the upper limits of normal ...    True  NCT00001860
# 78  Demonstrated tolerance to a test dose of s.c. ...    True  NCT00001860
# 79  Demonstrated responsiveness to a 100 ug s.c. S...    True  NCT00001860
# 80  Patients who are able to provide written infor...    True  NCT00001860
# 81  Patients demonstrating intolerance to a s.c. S...   False  NCT00001860
# 82  Patients who have received any prior treatment...   False  NCT00001860
# 83  Female patients who are pregnant or lactating,...   False  NCT00001860
# 84  Patients with compression of the optic chiasm ...   False  NCT00001860
# 85  Patients who require surgery for relief of any...   False  NCT00001860
# 86          Patients with symptomatic cholelithiasis.   False  NCT00001860
# 87  Patients who have congestive heart failure (NY...   False  NCT00001860
# 88  Patients with liver disease such as cirrhosis,...   False  NCT00001860
# 89  Patients with abnormal clinical laboratory val...   False  NCT00001860
# 90  Patients who have any current or prior medical...   False  NCT00001860
# 91  Patients who have a history of alcohol or drug...   False  NCT00001860
# 92  Patients who have received any investigational...   False  NCT00001860
# 93  Patients with any mental impairment limiting t...   False  NCT00001860
# 94  Patients who, for any reason, will be unable t...   False  NCT00001860
# 95                                 DIABETIC SUBJECTS:    True  NCT00001870
# 96  Males and non-pregnant females between the age...    True  NCT00001870
# 97  Patients found to have plasma vitamin C levels...    True  NCT00001870
# 98  VITAMIN C-DEFICIENT CLINICAL RESEARCH VOLUNTEERS:    True  NCT00001870
# 99  Adults between the ages of 18 and 35 in good g...    True  NCT00001870
#
#     TokenCount                                             Tokens  criteria_id
# 0           54  [Diagnosed, with, type, 2, diabetes, mellitus,...            0
# 1           26  [For, participants, aged, 40, years, or, older...            1
# 2           40  [For, participants, aged, 55, years, or, older...            2
# 3           16  [HbA1c, 7, 5, 9, if, on, more, drugs, or, 7, 5...            3
# 4           33  [Subjects, selected, for, this, study, will, b...            4
# 5            3               [Histologically, proven, gastrinoma]            5
# 6           19  [Evidence, of, metastatic, disease, or, locall...            6
# 7            9  [Progression, of, the, tumor, during, the, pre...            7
# 8           11  [The, following, pre, existing, conditions, wi...            8
# 9            3                       [Congestive, heart, failure]            9
# 10           6         [Proteinuria, greater, than, 1, gram, day]           10
# 11           7       [Serum, creatinine, greater, than, 1, 5, mg]           11
# 12           7       [Platelet, count, less, than, 100, 000, mm3]           12
# 13           7       [White, blood, count, less, than, 2500, mm3]           13
# 14           1                                        [Pregnancy]           14
# 15          43  [Subjects, for, receiving, oral, Omeprazole, w...           15
# 16          29  [Subjects, with, gastric, acid, hypersecretory...           16
# 17           9  [Patients, must, be, 18, years, of, age, or, o...           17
# 18          24  [Female, patients, of, childbearing, age, who,...           18
# 19          13  [Patients, who, develop, adverse, reactions, o...           19
# 20          47  [Subjects, selected, for, this, study, will, b...           20
# 21           3               [histologically, proven, gastrinoma]           21
# 22          18  [evidence, of, metastatic, tumor, by, one, or,...           22
# 23          15  [progression, of, tumor, size, during, the, pr...           23
# 24           5          [For, treatment, with, interferon, alpha]           24
# 25           3                       [Congestive, heart, failure]           25
# 26           4                      [Proteinuria, 3, or, greater]           26
# 27           7   [Creatinine, clearance, less, than, 30, ml, min]           27
# 28           9     [Platelet, count, less, than, 30, x, 10, 9, 1]           28
# 29          10  [White, blood, count, less, than, 4, x, 10, 9, 1]           29
# ..         ...                                                ...          ...
# 70          15  [Recent, weight, change, of, more, than, 3, of...           70
# 71          14  [Recent, use, within, six, months, of, anorexi...           71
# 72          16  [Physical, impairments, that, would, prevent, ...           72
# 73          10  [Male, or, female, patients, 18, years, of, ag...           73
# 74           8  [Newly, diagnosed, patients, with, acromegaly,...           74
# 75          13  [Presence, of, a, pituitary, tumor, greater, t...           75
# 76          40  [Lack, of, suppression, of, GH, to, less, than...           76
# 77          14  [IGF, 1, levels, above, the, upper, limits, of...           77
# 78          11  [Demonstrated, tolerance, to, a, test, dose, o...           78
# 79          35  [Demonstrated, responsiveness, to, a, 100, ug,...           79
# 80           9  [Patients, who, are, able, to, provide, writte...           80
# 81          12  [Patients, demonstrating, intolerance, to, a, ...           81
# 82          18  [Patients, who, have, received, any, prior, tr...           82
# 83          22  [Female, patients, who, are, pregnant, or, lac...           83
# 84          17  [Patients, with, compression, of, the, optic, ...           84
# 85          16  [Patients, who, require, surgery, for, relief,...           85
# 86           4      [Patients, with, symptomatic, cholelithiasis]           86
# 87          32  [Patients, who, have, congestive, heart, failu...           87
# 88          40  [Patients, with, liver, disease, such, as, cir...           88
# 89          30  [Patients, with, abnormal, clinical, laborator...           89
# 90          36  [Patients, who, have, any, current, or, prior,...           90
# 91          19  [Patients, who, have, a, history, of, alcohol,...           91
# 92          25  [Patients, who, have, received, any, investiga...           92
# 93          14  [Patients, with, any, mental, impairment, limi...           93
# 94          13  [Patients, who, for, any, reason, will, be, un...           94
# 95           2                               [DIABETIC, SUBJECTS]           95
# 96          29  [Males, and, non, pregnant, females, between, ...           96
# 97          31  [Patients, found, to, have, plasma, vitamin, C...           97
# 98           6  [VITAMIN, C, DEFICIENT, CLINICAL, RESEARCH, VO...           98
# 99          18  [Adults, between, the, ages, of, 18, and, 35, ...           99
#
# [100 rows x 6 columns]

# %% [markdown]
# # Tag, lemmatize, ngrammize
#
# Processes the extracted criteria with the NLTK POS tagger and lemmatizer and generates ngrams of 1-3 words (note: while unigrams are technically duplicated as 'Tokens', it will be more convenient to allow this and keep them in one column with bigrams and trigrams). Preprocesses the tokens by removing special characters and punctuation. Lemmata and ngrams are lowercased.

# %%
def __lemmatise(lemmatizer, r):
    wn_tags = {'NN': nltk.corpus.wordnet.NOUN, 'JJ': nltk.corpus.wordnet.ADJ, 'VB': nltk.corpus.wordnet.VERB,
               'RB': nltk.corpus.wordnet.ADV}
    return [(t[0], lemmatizer.lemmatize(t[0].lower(), pos=wn_tags.get(t[1][:2], nltk.corpus.wordnet.NOUN)).lower()) for
            t in r]


def tag_and_stem(data):
    print("Transforming data (tagging and lemmatising)")
    series = []
    lemmatizer = nltk.stem.WordNetLemmatizer()
    punct = '[%s]*' % re.escape(string.punctuation)
    pat = re.compile(r"^(%(p)s[\w\d]+%(p)s)+$" % {'p': punct}, re.UNICODE)
    # Itertuples is 50% faster than df.apply()
    for row in progressbar(data[['NctId', 'Tokens', 'criteria_id']].itertuples(), total=data.shape[0]):
        nct_id = row[1]
        toks = filter(lambda t: re.match(pat, t), row[2])
        cri_id = row[3]
        tags = nltk.pos_tag(toks)
        lemmas = __lemmatise(lemmatizer, tags)
        ngrams = []
        for n in (1, 2, 3):
            ngrams += list(nltk.ngrams([(lemma[1], tags[idx][1]) for idx, lemma in enumerate(lemmas)], n))
        s = {'criteria_id': cri_id, 'NctId': nct_id, 'Tokens': toks, 'Tags': tags, 'Lemmas': lemmas, 'Ngrams': ngrams}
        series.append(s)
    df = pd.DataFrame(series)
    return df

# %% [markdown]
# Read in the extracted criteria (stored in "ct_criteria.pckl" in the previous step), tag, lemmatize and ngrammize the data and store it as "ct_tagged.pckl".

# %%
data_dir = __mkdir(working_dir, "data", "diab")

criteria = pd.read_pickle(os.path.join(data_dir, 'ct_criteria.pckl'))
tagged = tag_and_stem(criteria)
tagged.to_pickle(os.path.join(data_dir, 'ct_tagged.pckl'))
# Out:
# Transforming data (tagging and lemmatising)

# %%
tagged = pd.read_pickle(os.path.join(data_dir, 'ct_tagged.pckl'))
tagged.head()
# Out:
#                                               Lemmas        NctId  \
# 0  [(Diagnosed, diagnose), (with, with), (type, t...  NCT00000620
# 1  [(For, for), (participants, participant), (age...  NCT00000620
# 2  [(For, for), (participants, participant), (age...  NCT00000620
# 3  [(HbA1c, hba1c), (7, 7), (5, 5), (9, 9), (if, ...  NCT00000620
# 4  [(Subjects, subject), (selected, select), (for...  NCT00001165
#
#                                               Ngrams  \
# 0  [((diagnose, VBN),), ((with, IN),), ((type, NN...
# 1  [((for, IN),), ((participant, NNS),), ((age, V...
# 2  [((for, IN),), ((participant, NNS),), ((age, V...
# 3  [((hba1c, NNP),), ((7, CD),), ((5, CD),), ((9,...
# 4  [((subject, NNS),), ((select, VBN),), ((for, I...
#
#                                                 Tags  \
# 0  [(Diagnosed, VBN), (with, IN), (type, NN), (2,...
# 1  [(For, IN), (participants, NNS), (aged, VBD), ...
# 2  [(For, IN), (participants, NNS), (aged, VBD), ...
# 3  [(HbA1c, NNP), (7, CD), (5, CD), (9, CD), (if,...
# 4  [(Subjects, NNS), (selected, VBN), (for, IN), ...
#
#                                               Tokens  criteria_id
# 0  [Diagnosed, with, type, 2, diabetes, mellitus,...            0
# 1  [For, participants, aged, 40, years, or, older...            1
# 2  [For, participants, aged, 55, years, or, older...            2
# 3  [HbA1c, 7, 5, 9, if, on, more, drugs, or, 7, 5...            3
# 4  [Subjects, selected, for, this, study, will, b...            4

# %% [markdown]
# # Filter criteria
# Filters out criteria composed entirely of function words and stopwords. Strips ngrams composed entirely of stop words/tags from the ngram list. By default this function uses the NTLK stopword list and all PTB tags except nouns. Additional lists of stop words and stop tags can be supplied with keyword arguments ("stop_words", "stop_tags"). Returns a tuple of dataframes, (filtered_criteria, excluded_criteria).
#
# (Note: this step generates a SettingWithCopyWarning. This is known and is a false positive.)

# %%
def __filter(values, idx, stops):
    return not set([t[idx] for t in values]) <= [x for x in stops]


def filter_criteria(data, user_stop_words=[], user_stop_tags=[]):
    print("Filtering criteria")
    default_stop_words = nltk.corpus.stopwords.words('english')
    default_stop_tags = ["$", "''", "(", ")", ",", "--", ".", ":", "CC", "CD", "DT",
                         "EX", "FW", "IN", "JJ", "JJR", "JJS", "LS", "MD",
                         "PDT", "POS", "PRP", "PRP$", "RB", "RBR", "RBS", "RP",
                         "SYM", "TO", "UH", "VB", "VBD", "VBG", "VBN", "VBP", "VBZ",
                         "WDT", "WP", "WP$", "WRB", "``"]
    print("Filtering stops")
    stop_words = set(default_stop_words + user_stop_words)
    stop_tags = set(default_stop_tags + user_stop_tags)
    excluded = pd.DataFrame()
    for col, idx, stops in (
            ('Lemmas', 0, stop_words),
            ('Tags', 1, stop_tags)):  
        data['Ngrams'] = data['Ngrams'].apply(lambda row: [ngram for ngram in row if __filter(ngram, idx, stops)])
        groups = data.groupby(lambda r: __filter(data[col].loc[r], 1, stops))
        data = groups.get_group(True)
        excluded = excluded.append(groups.get_group(False)) if groups.groups.has_key(False) else excluded
    return (data, excluded)

# %% [markdown]
# Read in the tagged criteria (stored in "ct_tagged.pckl" in the previous step), filter out noise and write the results to "ct_filtered.pckl" (the included criteria) and "ct_excluded.pckl" (the excluded criteria).

# %%
data_dir = __mkdir(working_dir, "data", "diab")

criteria = pd.read_pickle(os.path.join(data_dir, 'ct_tagged.pckl'))

# %%
incl, excl = filter_criteria(criteria)
incl.to_pickle(os.path.join(data_dir, 'ct_filtered.pckl'))
excl.to_pickle(os.path.join(data_dir, 'ct_excluded.pckl'))
# Out:
# Filtering criteria
# Filtering stops

# %% [markdown]
# ### Remove ngram duplicates

# %%
data_dir = __mkdir(working_dir, "data", "diab")
incl = pd.read_pickle(os.path.join(data_dir, 'ct_filtered.pckl'))
incl['Ngrams'] = incl['Ngrams'].apply(lambda ngrams: list(set(ngrams)))
incl.to_pickle(os.path.join(data_dir, 'ct_filtered.pckl'))
incl.head(100)
# Out:
#                                                Lemmas        NctId  \
# 0   [(Diagnosed, diagnose), (with, with), (type, t...  NCT00000620
# 1   [(For, for), (participants, participant), (age...  NCT00000620
# 2   [(For, for), (participants, participant), (age...  NCT00000620
# 3   [(HbA1c, hba1c), (7, 7), (5, 5), (9, 9), (if, ...  NCT00000620
# 4   [(Subjects, subject), (selected, select), (for...  NCT00001165
# 5   [(Histologically, histologically), (proven, pr...  NCT00001165
# 6   [(Evidence, evidence), (of, of), (metastatic, ...  NCT00001165
# 7   [(Progression, progression), (of, of), (the, t...  NCT00001165
# 8   [(The, the), (following, follow), (pre, pre), ...  NCT00001165
# 9   [(Congestive, congestive), (heart, heart), (fa...  NCT00001165
# 10  [(Proteinuria, proteinuria), (greater, great),...  NCT00001165
# 11  [(Serum, serum), (creatinine, creatinine), (gr...  NCT00001165
# 12  [(Platelet, platelet), (count, count), (less, ...  NCT00001165
# 13  [(White, white), (blood, blood), (count, count...  NCT00001165
# 14                           [(Pregnancy, pregnancy)]  NCT00001165
# 15  [(Subjects, subject), (for, for), (receiving, ...  NCT00001191
# 16  [(Subjects, subject), (with, with), (gastric, ...  NCT00001191
# 17  [(Patients, patient), (must, must), (be, be), ...  NCT00001191
# 18  [(Female, female), (patients, patient), (of, o...  NCT00001191
# 19  [(Patients, patient), (who, who), (develop, de...  NCT00001191
# 20  [(Subjects, subject), (selected, select), (for...  NCT00001228
# 21  [(histologically, histologically), (proven, pr...  NCT00001228
# 22  [(evidence, evidence), (of, of), (metastatic, ...  NCT00001228
# 23  [(progression, progression), (of, of), (tumor,...  NCT00001228
# 24  [(For, for), (treatment, treatment), (with, wi...  NCT00001228
# 25  [(Congestive, congestive), (heart, heart), (fa...  NCT00001228
# 26  [(Proteinuria, proteinuria), (3, 3), (or, or),...  NCT00001228
# 27  [(Creatinine, creatinine), (clearance, clearan...  NCT00001228
# 28  [(Platelet, platelet), (count, count), (less, ...  NCT00001228
# 29  [(White, white), (blood, blood), (count, count...  NCT00001228
# ..                                                ...          ...
# 70  [(Recent, recent), (weight, weight), (change, ...  NCT00001723
# 71  [(Recent, recent), (use, use), (within, within...  NCT00001723
# 72  [(Physical, physical), (impairments, impairmen...  NCT00001723
# 73  [(Male, male), (or, or), (female, female), (pa...  NCT00001860
# 74  [(Newly, newly), (diagnosed, diagnose), (patie...  NCT00001860
# 75  [(Presence, presence), (of, of), (a, a), (pitu...  NCT00001860
# 76  [(Lack, lack), (of, of), (suppression, suppres...  NCT00001860
# 77  [(IGF, igf), (1, 1), (levels, level), (above, ...  NCT00001860
# 78  [(Demonstrated, demonstrated), (tolerance, tol...  NCT00001860
# 79  [(Demonstrated, demonstrated), (responsiveness...  NCT00001860
# 80  [(Patients, patient), (who, who), (are, be), (...  NCT00001860
# 81  [(Patients, patient), (demonstrating, demonstr...  NCT00001860
# 82  [(Patients, patient), (who, who), (have, have)...  NCT00001860
# 83  [(Female, female), (patients, patient), (who, ...  NCT00001860
# 84  [(Patients, patient), (with, with), (compressi...  NCT00001860
# 85  [(Patients, patient), (who, who), (require, re...  NCT00001860
# 86  [(Patients, patient), (with, with), (symptomat...  NCT00001860
# 87  [(Patients, patient), (who, who), (have, have)...  NCT00001860
# 88  [(Patients, patient), (with, with), (liver, li...  NCT00001860
# 89  [(Patients, patient), (with, with), (abnormal,...  NCT00001860
# 90  [(Patients, patient), (who, who), (have, have)...  NCT00001860
# 91  [(Patients, patient), (who, who), (have, have)...  NCT00001860
# 92  [(Patients, patient), (who, who), (have, have)...  NCT00001860
# 93  [(Patients, patient), (with, with), (any, any)...  NCT00001860
# 94  [(Patients, patient), (who, who), (for, for), ...  NCT00001860
# 95        [(DIABETIC, diabetic), (SUBJECTS, subject)]  NCT00001870
# 96  [(Males, male), (and, and), (non, non), (pregn...  NCT00001870
# 97  [(Patients, patient), (found, find), (to, to),...  NCT00001870
# 98  [(VITAMIN, vitamin), (C, c), (DEFICIENT, defic...  NCT00001870
# 99  [(Adults, adult), (between, between), (the, th...  NCT00001870
#
#                                                Ngrams  \
# 0   [((association, NNP), (guideline, NNS), (which...
# 1   [((or, CC), (carotid, JJ), (revascularization,...
# 2   [((be, VB), (at, IN), (high, JJ)), ((to, TO),)...
# 3   [((5, CD), (9, CD), (if, IN)), ((on, IN), (mor...
# 4   [((suspected, NNP), (abnormality, NNPS), (of, ...
# 5   [((histologically, RB), (prove, VBN)), ((prove...
# 6   [((of, IN), (metastatic, JJ)), ((invasive, JJ)...
# 7   [((6, CD),), ((tumor, NN), (during, IN), (the,...
# 8   [((condition, NNS), (will, MD), (exclude, VB))...
# 9   [((congestive, JJ), (heart, NN), (failure, NN)...
# 10  [((proteinuria, NNP), (great, JJR)), ((day, NN...
# 11  [((5, CD),), ((creatinine, NN),), ((1, CD),), ...
# 12  [((count, VBD), (less, JJR)), ((less, JJR), (t...
# 13  [((count, NN), (less, JJR)), ((blood, VBD),), ...
# 14                              [((pregnancy, NNP),)]
# 15  [((hypersecretion, NN),), ((who, WP), (have, V...
# 16  [((eligible, JJ),), ((who, WP), (be, VBP)), ((...
# 17  [((be, VB),), ((age, NN), (or, CC), (old, JJR)...
# 18  [((be, VB),), ((exclude, VBN),), ((pregnant, J...
# 19  [((adverse, VBP), (reaction, NNS), (or, CC)), ...
# 20  [((to, TO),), ((syndrome, NN),), ((with, IN), ...
# 21  [((histologically, RB), (prove, VBN)), ((prove...
# 22  [((one, CD), (or, CC)), ((or, CC), (octreoscan...
# 23  [((6, CD),), ((tumor, NN), (size, NN), (during...
# 24  [((interferon, NN),), ((with, IN), (interferon...
# 25  [((congestive, JJ), (heart, NN), (failure, NN)...
# 26  [((proteinuria, NNP), (3, CD)), ((or, CC), (gr...
# 27  [((clearance, NN), (less, JJR)), ((clearance, ...
# 28  [((10, CD),), ((platelet, NNP),), ((30, CD), (...
# 29  [((blood, VBD),), ((count, NN), (less, JJR), (...
# ..                                                ...
# 70  [((3, CD),), ((more, JJR), (than, IN)), ((in, ...
# 71  [((of, IN), (weight, NN), (reduction, NN)), ((...
# 72  [((either, DT), (the, DT), (walk, NN)), ((comp...
# 73  [((or, CC), (female, JJ)), ((patient, NNS),), ...
# 74  [((untreated, VBN),), ((newly, RB), (diagnose,...
# 75  [((mm, NN), (at, IN), (great, JJS)), ((great, ...
# 76  [((than, IN), (one, CD), (ng, NN)), ((gh, NNP)...
# 77  [((above, IN), (the, DT)), ((level, NNS), (abo...
# 78  [((to, TO), (a, DT), (test, NN)), ((s, NNS), (...
# 79  [((50, CD), (of, IN), (the, DT)), ((ng, NN), (...
# 80  [((who, WP), (be, VBP)), ((consent, NN),), ((t...
# 81  [((octreotide, NN),), ((s, NN), (c, NN), (sand...
# 82  [((for, IN),), ((any, DT), (prior, RB), (treat...
# 83  [((method, NN),), ((pregnant, JJ),), ((practic...
# 84  [((patient, NNS), (with, IN), (compression, NN...
# 85  [((of, IN), (any, DT), (neurologic, JJ)), ((si...
# 86  [((symptomatic, JJ),), ((patient, NNS), (with,...
# 87  [((precede, VBG),), ((failure, NN), (nyha, NNP...
# 88  [((chronic, JJ), (persistent, NN), (hepatitis,...
# 89  [((clinically, RB),), ((be, VB),), ((laborator...
# 90  [((s, NNS), (medical, NNP)), ((the, DT), (opin...
# 91  [((a, DT), (history, NN)), ((to, TO),), ((alco...
# 92  [((investigational, JJ), (drug, NN)), ((to, TO...
# 93  [((all, DT), (study, NN)), ((to, TO),), ((thei...
# 94  [((who, WP), (for, IN), (any, DT)), ((be, VB),...
# 95  [((subject, NNS),), ((diabetic, JJ),), ((diabe...
# 96  [((type, NN), (2, CD)), ((or, CC), (oral, JJ))...
# 97  [((vitamin, NN), (c, NNP), (level, NNS)), ((be...
# 98  [((c, NNP), (deficient, NNP)), ((c, NNP),), ((...
# 99  [((35, CD), (in, IN)), ((health, NN), (and, CC...
#
#                                                  Tags  \
# 0   [(Diagnosed, VBN), (with, IN), (type, NN), (2,...
# 1   [(For, IN), (participants, NNS), (aged, VBD), ...
# 2   [(For, IN), (participants, NNS), (aged, VBD), ...
# 3   [(HbA1c, NNP), (7, CD), (5, CD), (9, CD), (if,...
# 4   [(Subjects, NNS), (selected, VBN), (for, IN), ...
# 5   [(Histologically, RB), (proven, VBN), (gastrin...
# 6   [(Evidence, NN), (of, IN), (metastatic, JJ), (...
# 7   [(Progression, NN), (of, IN), (the, DT), (tumo...
# 8   [(The, DT), (following, VBG), (pre, NN), (exis...
# 9      [(Congestive, JJ), (heart, NN), (failure, NN)]
# 10  [(Proteinuria, NNP), (greater, JJR), (than, IN...
# 11  [(Serum, NNP), (creatinine, NN), (greater, JJR...
# 12  [(Platelet, NNP), (count, VBD), (less, JJR), (...
# 13  [(White, NNP), (blood, VBD), (count, NN), (les...
# 14                                 [(Pregnancy, NNP)]
# 15  [(Subjects, NNS), (for, IN), (receiving, VBG),...
# 16  [(Subjects, NNS), (with, IN), (gastric, JJ), (...
# 17  [(Patients, NNS), (must, MD), (be, VB), (18, C...
# 18  [(Female, NNP), (patients, NNS), (of, IN), (ch...
# 19  [(Patients, NNS), (who, WP), (develop, VB), (a...
# 20  [(Subjects, NNS), (selected, VBN), (for, IN), ...
# 21  [(histologically, RB), (proven, VBN), (gastrin...
# 22  [(evidence, NN), (of, IN), (metastatic, JJ), (...
# 23  [(progression, NN), (of, IN), (tumor, NN), (si...
# 24  [(For, IN), (treatment, NN), (with, IN), (inte...
# 25     [(Congestive, JJ), (heart, NN), (failure, NN)]
# 26  [(Proteinuria, NNP), (3, CD), (or, CC), (great...
# 27  [(Creatinine, NNP), (clearance, NN), (less, JJ...
# 28  [(Platelet, NNP), (count, VBD), (less, JJR), (...
# 29  [(White, NNP), (blood, VBD), (count, NN), (les...
# ..                                                ...
# 70  [(Recent, JJ), (weight, NN), (change, NN), (of...
# 71  [(Recent, JJ), (use, NN), (within, IN), (six, ...
# 72  [(Physical, JJ), (impairments, NNS), (that, WD...
# 73  [(Male, NNP), (or, CC), (female, JJ), (patient...
# 74  [(Newly, RB), (diagnosed, VBN), (patients, NNS...
# 75  [(Presence, NN), (of, IN), (a, DT), (pituitary...
# 76  [(Lack, NNP), (of, IN), (suppression, NN), (of...
# 77  [(IGF, NNP), (1, CD), (levels, NNS), (above, I...
# 78  [(Demonstrated, NNP), (tolerance, NN), (to, TO...
# 79  [(Demonstrated, NNP), (responsiveness, NN), (t...
# 80  [(Patients, NNS), (who, WP), (are, VBP), (able...
# 81  [(Patients, NNS), (demonstrating, VBG), (intol...
# 82  [(Patients, NNS), (who, WP), (have, VBP), (rec...
# 83  [(Female, NNP), (patients, NNS), (who, WP), (a...
# 84  [(Patients, NNS), (with, IN), (compression, NN...
# 85  [(Patients, NNS), (who, WP), (require, RB), (s...
# 86  [(Patients, NNS), (with, IN), (symptomatic, JJ...
# 87  [(Patients, NNS), (who, WP), (have, VBP), (con...
# 88  [(Patients, NNS), (with, IN), (liver, NN), (di...
# 89  [(Patients, NNS), (with, IN), (abnormal, JJ), ...
# 90  [(Patients, NNS), (who, WP), (have, VBP), (any...
# 91  [(Patients, NNS), (who, WP), (have, VBP), (a, ...
# 92  [(Patients, NNS), (who, WP), (have, VBP), (rec...
# 93  [(Patients, NNS), (with, IN), (any, DT), (ment...
# 94  [(Patients, NNS), (who, WP), (for, IN), (any, ...
# 95                  [(DIABETIC, JJ), (SUBJECTS, NNS)]
# 96  [(Males, NNS), (and, CC), (non, NN), (pregnant...
# 97  [(Patients, NNS), (found, VBD), (to, TO), (hav...
# 98  [(VITAMIN, NNP), (C, NNP), (DEFICIENT, NNP), (...
# 99  [(Adults, NNS), (between, IN), (the, DT), (age...
#
#                                                Tokens  criteria_id
# 0   [Diagnosed, with, type, 2, diabetes, mellitus,...            0
# 1   [For, participants, aged, 40, years, or, older...            1
# 2   [For, participants, aged, 55, years, or, older...            2
# 3   [HbA1c, 7, 5, 9, if, on, more, drugs, or, 7, 5...            3
# 4   [Subjects, selected, for, this, study, will, b...            4
# 5                [Histologically, proven, gastrinoma]            5
# 6   [Evidence, of, metastatic, disease, or, locall...            6
# 7   [Progression, of, the, tumor, during, the, pre...            7
# 8   [The, following, pre, existing, conditions, wi...            8
# 9                        [Congestive, heart, failure]            9
# 10         [Proteinuria, greater, than, 1, gram, day]           10
# 11       [Serum, creatinine, greater, than, 1, 5, mg]           11
# 12       [Platelet, count, less, than, 100, 000, mm3]           12
# 13       [White, blood, count, less, than, 2500, mm3]           13
# 14                                        [Pregnancy]           14
# 15  [Subjects, for, receiving, oral, Omeprazole, w...           15
# 16  [Subjects, with, gastric, acid, hypersecretory...           16
# 17  [Patients, must, be, 18, years, of, age, or, o...           17
# 18  [Female, patients, of, childbearing, age, who,...           18
# 19  [Patients, who, develop, adverse, reactions, o...           19
# 20  [Subjects, selected, for, this, study, will, b...           20
# 21               [histologically, proven, gastrinoma]           21
# 22  [evidence, of, metastatic, tumor, by, one, or,...           22
# 23  [progression, of, tumor, size, during, the, pr...           23
# 24          [For, treatment, with, interferon, alpha]           24
# 25                       [Congestive, heart, failure]           25
# 26                      [Proteinuria, 3, or, greater]           26
# 27   [Creatinine, clearance, less, than, 30, ml, min]           27
# 28     [Platelet, count, less, than, 30, x, 10, 9, 1]           28
# 29  [White, blood, count, less, than, 4, x, 10, 9, 1]           29
# ..                                                ...          ...
# 70  [Recent, weight, change, of, more, than, 3, of...           70
# 71  [Recent, use, within, six, months, of, anorexi...           71
# 72  [Physical, impairments, that, would, prevent, ...           72
# 73  [Male, or, female, patients, 18, years, of, ag...           73
# 74  [Newly, diagnosed, patients, with, acromegaly,...           74
# 75  [Presence, of, a, pituitary, tumor, greater, t...           75
# 76  [Lack, of, suppression, of, GH, to, less, than...           76
# 77  [IGF, 1, levels, above, the, upper, limits, of...           77
# 78  [Demonstrated, tolerance, to, a, test, dose, o...           78
# 79  [Demonstrated, responsiveness, to, a, 100, ug,...           79
# 80  [Patients, who, are, able, to, provide, writte...           80
# 81  [Patients, demonstrating, intolerance, to, a, ...           81
# 82  [Patients, who, have, received, any, prior, tr...           82
# 83  [Female, patients, who, are, pregnant, or, lac...           83
# 84  [Patients, with, compression, of, the, optic, ...           84
# 85  [Patients, who, require, surgery, for, relief,...           85
# 86      [Patients, with, symptomatic, cholelithiasis]           86
# 87  [Patients, who, have, congestive, heart, failu...           87
# 88  [Patients, with, liver, disease, such, as, cir...           88
# 89  [Patients, with, abnormal, clinical, laborator...           89
# 90  [Patients, who, have, any, current, or, prior,...           90
# 91  [Patients, who, have, a, history, of, alcohol,...           91
# 92  [Patients, who, have, received, any, investiga...           92
# 93  [Patients, with, any, mental, impairment, limi...           93
# 94  [Patients, who, for, any, reason, will, be, un...           94
# 95                               [DIABETIC, SUBJECTS]           95
# 96  [Males, and, non, pregnant, females, between, ...           96
# 97  [Patients, found, to, have, plasma, vitamin, C...           97
# 98  [VITAMIN, C, DEFICIENT, CLINICAL, RESEARCH, VO...           98
# 99  [Adults, between, the, ages, of, 18, and, 35, ...           99
#
# [100 rows x 6 columns]

# %%
excl = pd.read_pickle(os.path.join(data_dir, 'ct_excluded.pckl'))
excl.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
