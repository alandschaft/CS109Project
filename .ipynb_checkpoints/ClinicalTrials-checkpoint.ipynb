# %% [markdown]
# # Initial setup
#
# Let's import the required libraries and set up global variables for the rest of the script.

# %%
# coding: utf-8

import csv
import os
import re
import shutil
import string
import tempfile
import zipfile
from collections import defaultdict
from lxml import objectify

import nltk
import pandas as pd
import requests

# %%
# Directory to hold the downloaded data and the serialized Pandas dataframes. 
# We'll create a new temporary directory here.
#data_dir = tempfile.mkdtemp()
#data_dir='C:\Study\CS102\project\data-dir'
data_dir='../data'
print("Working directory: %s" % data_dir)
# Out:
# Working directory: ../data

# %% [markdown]
# # Data download
#
# Download CSV data from clinicaltrials.gov. The data will be written in the working directory specified above as  [data_dir]/study_fields.csv.
#
# For clinicaltrials.gov, a search term needs to be specified. In this example, we'll download search results for the term "seizure".

# %%
def download_ctgov(dest_dir, search_term):
    print("Downloading clinicaltrials.gov results for '%s' to %s" % (search_term, dest_dir))
    dl_url = "https://clinicaltrials.gov/ct2/results/download?down_stds=all&down_typ=results&down_flds=all&down_fmt=xml&term=%s&show_down=Y" % search_term

    # Download the zipped data and extract it to the output directory
    out_path = os.path.join(dest_dir, "download_ctgov.zip")
    with open(out_path, 'wb') as fh:
        r = requests.get(dl_url)
        for block in r.iter_content(1024):
            fh.write(block)
    with zipfile.ZipFile(out_path, 'r') as z:
        z.extractall(dest_dir)

# %%
download_ctgov(data_dir, "seizure")

# %% [markdown]
# # Pandas import
#
# Convert the downloaded CSV data to Pandas dataframes and serialize them as Python pickles. The function reads XML files from the working directory and writes to "ctgov.pckl"

# %%
def ctgov_to_dataframe(src_dir):
    # Get all XML files in the data directory
    print("Transforming cliniclatrials download (%s) to dataframe" % (src_dir))
    data = []
    for f in [_ for _ in os.listdir(src_dir) if _.endswith('.xml')]:
        xml = objectify.parse(os.path.join(src_dir, f))
        root = xml.getroot()
        d = defaultdict(list)
        for t in root.iter():
            if t.text:
                key = re.sub(r'\[\d+\]', '', xml.getpath(t)).replace('/clinical_study/', '').replace('/', '.')
                val = t.text.strip()
                d[key].append(val)
        d = {k: v[0] if len(v) == 1 else v for k, v in d.items()}
        data.append(d)
    data_frame = pd.DataFrame(data)
    return data_frame

# %% [markdown]
# # Writing dataframes
# Transform the downloaded data to Pandas dataframes and seialize them as Pytohn pickles.

# %%
ct_df = ctgov_to_dataframe(data_dir)
ct_df.to_pickle(os.path.join(data_dir, 'ctgov.pckl'))
# Out:
# Transforming cliniclatrials download (C:\Study\CS102\project\data-dir) to dataframe

# %% [markdown]
# # Reading dataframes
#
# Read the pickled data back into Pandas and display the first 5 records. In this example, the pickled dataframe is serialized to "ctgov.pckl" in the working directory.

# %%
ctgov_data = pd.read_pickle(os.path.join(data_dir, 'ctgov.pckl'))
ctgov_data.head()
# Out:
#   acronym arm_group.arm_group_label arm_group.arm_group_type  \
# 0     NaN                       NaN                      NaN
# 1     NaN                       NaN                      NaN
# 2     NaN                       NaN                      NaN
# 3     NaN                       NaN                      NaN
# 4     NaN          Copper histidine             Experimental
#
#   arm_group.description biospec_descr.textblock biospec_retention  \
# 0                   NaN                     NaN               NaN
# 1                   NaN                     NaN               NaN
# 2                   NaN                     NaN               NaN
# 3                   NaN                     NaN               NaN
# 4                   NaN                     NaN               NaN
#
#                              brief_summary.textblock  \
# 0  This study is designed to evaluate patients wi...
# 1  This study will allow researchers to use vario...
# 2  The purpose of this study is to evaluate, trea...
# 3  Our past ultrasound research has indicated a n...
# 4  Menkes Disease is a genetic disorder affecting...
#
#                                          brief_title  \
# 0     Monitoring Patients With Uncontrolled Epilepsy
# 1  Neuropsychological Evaluation of Psychiatric a...
# 2  Treatment of Patients With Cysticercosis With ...
# 3  Development of Normative Ultrasound Databases ...
# 4       Copper Histidine Therapy for Menkes Diseases
#
#   clinical_results.baseline.group_list.group.description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [Classic Menkes disease: Copper histidine trea...
#
#   clinical_results.baseline.group_list.group.title     ...      \
# 0                                              NaN     ...
# 1                                              NaN     ...
# 2                                              NaN     ...
# 3                                              NaN     ...
# 4                       [Early, Late, Mild, Total]     ...
#
#   sponsors.collaborator.agency sponsors.collaborator.agency_class  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                          NaN                                NaN
#
#                         sponsors.lead_sponsor.agency  \
# 0  National Institute of Neurological Disorders a...
# 1         National Institute of Mental Health (NIMH)
# 2  National Institute of Allergy and Infectious D...
# 3  National Institutes of Health Clinical Center ...
# 4  Eunice Kennedy Shriver National Institute of C...
#
#   sponsors.lead_sponsor.agency_class     start_date  \
# 0                                NIH  November 1975
# 1                                NIH   October 1983
# 2                                NIH      July 1985
# 3                                NIH  February 1987
# 4                                NIH      June 1990
#
#                                         study_design      study_type  \
# 0                                                N/A   Observational
# 1                                                N/A   Observational
# 2                      Time Perspective: Prospective   Observational
# 3                                                N/A   Observational
# 4  Endpoint Classification: Safety/Efficacy Study...  Interventional
#
#   target_duration verification_date why_stopped
# 0             NaN      January 2002         NaN
# 1             NaN     December 2006         NaN
# 2             NaN     December 2014         NaN
# 3             NaN      January 2000         NaN
# 4             NaN    September 2015         NaN
#
# [5 rows x 187 columns]

# %% [markdown]
# # Extract criteria
#
# Read inthe serialized data from clinicaltrials.gov and extract inclusion/exlcusion criteria, one per row. Output a Series(id_info.nct_id, Criteria, Inclusion, TokenCount).

# %%
def __process_criteria(data):
    pat = r"^([\w\-]*\s*){0,5}%s criteria[\s\w\(\),]*:"
    inpat = re.compile(pat % 'inclusion', re.UNICODE)
    expat = re.compile(pat % 'exclusion', re.UNICODE)
    try:
        incl = True
        id = data[1]
        txt = [_.strip() for _ in data[2].split(u'\n\n')]
        for l in txt:
            if re.match(inpat, l.lower()):
                incl = True
            elif re.match(expat, l.lower()):
                incl = False
            else:
                toks = nltk.word_tokenize(l)
                s = {'NctId': id, 'Criteria': unicode(l), 'Include': incl, 'Tokens': toks, 'TokenCount': len(toks)}
                yield s
    except Exception as e:
        print("Error processing row %s: %s" % (data[2], e))


def extract_criteria(data):
    print("Transforming data (extracting criteria)")
    transformed = [s for row in data[['id_info.nct_id', 'eligibility.criteria.textblock']].itertuples() for s in
                   __process_criteria(row)]
    df = pd.DataFrame(transformed)
    return df

# %% [markdown]
# Transform the data and write the result to a file. (You'll notice that the script logs an error for one row. This is expected and results from that row being a "NaN".)

# %%
# The data was read in in the previous step: ctgov_data = pd.read_pickle(os.path.join(data_dir, 'ctgov.pckl'))
criteria = extract_criteria(ctgov_data)
criteria.to_pickle(os.path.join(data_dir, 'ct_criteria.pckl'))
# Out:
# Transforming data (extracting criteria)
# Error processing row nan: 'float' object has no attribute 'split'

# %% [markdown]
# Read back the data and display a record selected by column value.

# %%
criteria.loc[criteria['NctId'] == 'NCT01373190']
# Out:
#                                                Criteria Include        NctId  \
# 9611  1. Diagnosis of Partial/Focal Onset Epilepsy (...    True  NCT01373190
# 9612                                      2. Ages 18-70    True  NCT01373190
# 9613                                       1. Pregnancy   False  NCT01373190
# 9614  2. Recent trauma such as motor vehicle acciden...   False  NCT01373190
# 9615  3. Currently on medication, other than for epi...   False  NCT01373190
# 9616  4. If diagnosed with a condition which could a...   False  NCT01373190
# 9617                        1. Irritable bowel syndrome   False  NCT01373190
# 9618                                 2. Crohn's disease   False  NCT01373190
# 9619                              3. Ulcerative colitis   False  NCT01373190
# 9620  4. Migraine headache with abdominal manifestation   False  NCT01373190
# 9621  1. No history or diagnosis of any seizure diso...    True  NCT01373190
# 9622                                      2. Ages 18-70    True  NCT01373190
# 9623                                       1. Pregnancy   False  NCT01373190
# 9624  2. Recent trauma such as motor vehicle acciden...   False  NCT01373190
# 9625  3. Currently on medication, other than for epi...   False  NCT01373190
# 9626  4. If diagnosed with a condition which could a...   False  NCT01373190
# 9627                        1. Irritable bowel syndrome   False  NCT01373190
# 9628                                 2. Crohn's disease   False  NCT01373190
# 9629                              3. Ulcerative colitis   False  NCT01373190
# 9630  4. Migraine headache with abdominal manifestation   False  NCT01373190
#
#       TokenCount                                             Tokens
# 9611          13  [1, ., Diagnosis, of, Partial/Focal, Onset, Ep...
# 9612           4                                [2, ., Ages, 18-70]
# 9613           3                                  [1, ., Pregnancy]
# 9614          15  [2, ., Recent, trauma, such, as, motor, vehicl...
# 9615          22  [3, ., Currently, on, medication, ,, other, th...
# 9616          15  [4, ., If, diagnosed, with, a, condition, whic...
# 9617           5                 [1, ., Irritable, bowel, syndrome]
# 9618           5                         [2, ., Crohn, 's, disease]
# 9619           4                        [3, ., Ulcerative, colitis]
# 9620           7  [4, ., Migraine, headache, with, abdominal, ma...
# 9621          10  [1, ., No, history, or, diagnosis, of, any, se...
# 9622           4                                [2, ., Ages, 18-70]
# 9623           3                                  [1, ., Pregnancy]
# 9624          15  [2, ., Recent, trauma, such, as, motor, vehicl...
# 9625          22  [3, ., Currently, on, medication, ,, other, th...
# 9626          15  [4, ., If, diagnosed, with, a, condition, whic...
# 9627           5                 [1, ., Irritable, bowel, syndrome]
# 9628           5                         [2, ., Crohn, 's, disease]
# 9629           4                        [3, ., Ulcerative, colitis]
# 9630           7  [4, ., Migraine, headache, with, abdominal, ma...

# %% [markdown]
# # Tag, lemmatize, ngrammize
#
# Processes the extracted criteria with the NLTK POS tagger and lemmatizer and generates ngrams of 1-3 words (note: while unigrams are technically duplicated as 'Tokens', it will be more convenient to allow this and keep them in one column with bigrams and trigrams). Preprocesses the tokens by removing special characters and punctuation. Lemmata and ngrams are lowercased.

# %%
def __lemmatise(lemmatizer, r):
    wn_tags = {'NN': nltk.corpus.wordnet.NOUN, 'JJ': nltk.corpus.wordnet.ADJ, 'VB': nltk.corpus.wordnet.VERB,
               'RB': nltk.corpus.wordnet.ADV}
    return [(t[0], lemmatizer.lemmatize(t[0].lower(), pos=wn_tags.get(t[1][:2], nltk.corpus.wordnet.NOUN)).lower()) for
            t in r]


def tag_and_stem(data):
    print("Transforming data (tagging and lemmatising)")
    series = []
    lemmatizer = nltk.stem.WordNetLemmatizer()
    punct = '[%s]*' % re.escape(string.punctuation)
    pat = re.compile(r"^(%(p)s[\w\d]+%(p)s)+$" % {'p': punct}, re.UNICODE)
    # Itertuples is 50% faster than df.apply()
    for row in data[['NctId', 'Tokens']].itertuples():
        id = row[1]
        toks = filter(lambda t: re.match(pat, t), row[2])
        tags = nltk.pos_tag(toks)
        lemmas = __lemmatise(lemmatizer, tags)
        ngrams = []
        for n in (1, 3):
            ngrams += list(nltk.ngrams([(lemma[1], tags[idx][1]) for idx, lemma in enumerate(lemmas)], n))
        s = {'NctId': id, 'Tokens': toks, 'Tags': tags, 'Lemmas': lemmas, 'Ngrams': ngrams}
        series.append(s)
    df = pd.DataFrame(series)
    return df

# %% [markdown]
# Read in the extracted criteria (by stored in "ct_criteria.pckl" in the previous step), tag, lemmatize and ngrammize the data and store it as "ct_tagged.pckl".

# %%
criteria = pd.read_pickle(os.path.join(data_dir, 'ct_criteria.pckl'))
tagged = tag_and_stem(criteria)
tagged.to_pickle(os.path.join(data_dir, 'ct_tagged.pckl'))
# Out:
# Transforming data (tagging and lemmatising)

# %%
tagged.head()
# Out:
#                                               Lemmas        NctId  \
# 0  [(History, history), (of, of), (uncontrolled, ...  NCT00001149
# 1  [(Seizure, seizure), (frequency, frequency), (...  NCT00001149
# 2  [(Patients, patient), (of, of), (any, any), (a...  NCT00001149
# 3  [(Patients, patient), (and, and), (parents, pa...  NCT00001149
# 4                              [(Patients, patient)]  NCT00001192
#
#                                               Ngrams  \
# 0  [((history, NN),), ((of, IN),), ((uncontrolled...
# 1  [((seizure, NN),), ((frequency, NN),), ((by, I...
# 2  [((patient, NNS),), ((of, IN),), ((any, DT),),...
# 3  [((patient, NNS),), ((and, CC),), ((parent, NN...
# 4                                [((patient, NNS),)]
#
#                                                 Tags  \
# 0  [(History, NN), (of, IN), (uncontrolled, VBN),...
# 1  [(Seizure, NN), (frequency, NN), (by, IN), (hi...
# 2  [(Patients, NNS), (of, IN), (any, DT), (age, N...
# 3  [(Patients, NNS), (and, CC), (parents, NNS), (...
# 4                                  [(Patients, NNS)]
#
#                                               Tokens
# 0  [History, of, uncontrolled, seizures, at, the,...
# 1  [Seizure, frequency, by, history, must, be, su...
# 2        [Patients, of, any, age, may, be, accepted]
# 3  [Patients, and, parents, or, guardians, if, ap...
# 4                                         [Patients]

# %% [markdown]
# # Filter criteria
# Filters out criteria composed entirely of function words and stopwords. Strips ngrams composed entirely of stop words/tags from the ngram list. By default this function uses the NTLK stopword list and all PTB tags except nouns. Additional lists of stop words and stop tags can be supplied with keyword arguments ("stop_words", "stop_tags"). Returns a tuple of dataframes, (filtered_criteria, excluded_criteria).
#
# (Note: this step generates a SettingWithCopyWarning. This is known and is a false positive.)

# %%
def __filter(values, idx, stops):
    return not set([t[idx] for t in values]) <= stops


def filter_criteria(data, user_stop_words=[], user_stop_tags=[]):
    print("Filtering criteria")
    default_stop_words = nltk.corpus.stopwords.words('english')
    default_stop_tags = ["$", "''", "(", ")", ",", "--", ".", ":", "CC", "CD", "DT",
                         "EX", "FW", "IN", "JJ", "JJR", "JJS", "LS", "MD",
                         "PDT", "POS", "PRP", "PRP$", "RB", "RBR", "RBS", "RP",
                         "SYM", "TO", "UH", "VB", "VBD", "VBG", "VBN", "VBP", "VBZ",
                         "WDT", "WP", "WP$", "WRB", "``"]
    print("Filtering stops")
    stop_words = set(default_stop_words + user_stop_words)
    stop_tags = set(default_stop_tags + user_stop_tags)
    excluded = pd.DataFrame()
    for col, idx, stops in (
            ('Lemmas', 0, stop_words),
            ('Tags', 1, stop_tags)):  # Lemma filtering excludes 18 rows, tag filtering excludes 205
        data['Ngrams'] = data['Ngrams'].apply(lambda row: [ngram for ngram in row if __filter(ngram, idx, stops)])
        groups = data.groupby(lambda r: __filter(data[col].loc[r], 1, stops))
        data = groups.get_group(True)
        excluded = excluded.append(groups.get_group(False)) if groups.groups.has_key(False) else excluded
    return (data, excluded)

# %% [markdown]
# Read in the tagged criteria (stored in "ct_tagged.pckl" in the previous step), filter out noise and write the results to "ct_filtered.pckl" (the included criteria) and "ct_excluded.pckl" (the excluded criteria).

# %%
criteria = pd.read_pickle(os.path.join(data_dir, 'ct_tagged.pckl'))
incl, excl = filter_criteria(criteria)
incl.to_pickle(os.path.join(data_dir, 'ct_filtered.pckl'))
excl.to_pickle(os.path.join(data_dir, 'ct_excluded.pckl'))
# Out:
# Filtering criteria
# Filtering stops
# C:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
incl.head()
# Out:
#                                               Lemmas        NctId  \
# 0  [(History, history), (of, of), (uncontrolled, ...  NCT00001149
# 1  [(Seizure, seizure), (frequency, frequency), (...  NCT00001149
# 2  [(Patients, patient), (of, of), (any, any), (a...  NCT00001149
# 3  [(Patients, patient), (and, and), (parents, pa...  NCT00001149
# 4                              [(Patients, patient)]  NCT00001192
#
#                                               Ngrams  \
# 0  [((history, NN),), ((seizure, NNS),), ((presen...
# 1  [((seizure, NN),), ((frequency, NN),), ((histo...
# 2  [((patient, NNS),), ((age, NN),), ((patient, N...
# 3  [((patient, NNS),), ((parent, NNS),), ((guardi...
# 4                                [((patient, NNS),)]
#
#                                                 Tags  \
# 0  [(History, NN), (of, IN), (uncontrolled, VBN),...
# 1  [(Seizure, NN), (frequency, NN), (by, IN), (hi...
# 2  [(Patients, NNS), (of, IN), (any, DT), (age, N...
# 3  [(Patients, NNS), (and, CC), (parents, NNS), (...
# 4                                  [(Patients, NNS)]
#
#                                               Tokens
# 0  [History, of, uncontrolled, seizures, at, the,...
# 1  [Seizure, frequency, by, history, must, be, su...
# 2        [Patients, of, any, age, may, be, accepted]
# 3  [Patients, and, parents, or, guardians, if, ap...
# 4                                         [Patients]

# %%
incl.Ngrams[0]
# Out:
# [((u'history', 'NN'),),
#  ((u'seizure', 'NNS'),),
#  ((u'present', 'NN'),),
#  ((u'time', 'NN'),),
#  ((u'month', 'NNS'),),
#  ((u'year', 'NNS'),),
#  ((u'pattern', 'NN'),),
#  ((u'seizure', 'NNS'),),
#  ((u'month', 'NNS'),),
#  ((u'admission', 'NN'),),
#  ((u'history', 'NN'), (u'of', 'IN'), (u'uncontrolled', 'VBN')),
#  ((u'of', 'IN'), (u'uncontrolled', 'VBN'), (u'seizure', 'NNS')),
#  ((u'uncontrolled', 'VBN'), (u'seizure', 'NNS'), (u'at', 'IN')),
#  ((u'seizure', 'NNS'), (u'at', 'IN'), (u'the', 'DT')),
#  ((u'at', 'IN'), (u'the', 'DT'), (u'present', 'NN')),
#  ((u'the', 'DT'), (u'present', 'NN'), (u'time', 'NN')),
#  ((u'present', 'NN'), (u'time', 'NN'), (u'at', 'IN')),
#  ((u'time', 'NN'), (u'at', 'IN'), (u'least', 'JJS')),
#  ((u'during', 'IN'), (u'6', 'CD'), (u'month', 'NNS')),
#  ((u'6', 'CD'), (u'month', 'NNS'), (u'of', 'IN')),
#  ((u'month', 'NNS'), (u'of', 'IN'), (u'the', 'DT')),
#  ((u'past', 'JJ'), (u'3', 'CD'), (u'year', 'NNS')),
#  ((u'3', 'CD'), (u'year', 'NNS'), (u'and', 'CC')),
#  ((u'year', 'NNS'), (u'and', 'CC'), (u'preferably', 'RB')),
#  ((u'a', 'DT'), (u'continuous', 'JJ'), (u'pattern', 'NN')),
#  ((u'continuous', 'JJ'), (u'pattern', 'NN'), (u'of', 'IN')),
#  ((u'pattern', 'NN'), (u'of', 'IN'), (u'seizure', 'NNS')),
#  ((u'of', 'IN'), (u'seizure', 'NNS'), (u'during', 'IN')),
#  ((u'seizure', 'NNS'), (u'during', 'IN'), (u'the', 'DT')),
#  ((u'the', 'DT'), (u'few', 'JJ'), (u'month', 'NNS')),
#  ((u'few', 'JJ'), (u'month', 'NNS'), (u'prior', 'RB')),
#  ((u'month', 'NNS'), (u'prior', 'RB'), (u'to', 'TO')),
#  ((u'prior', 'RB'), (u'to', 'TO'), (u'admission', 'NN'))]

# %%
excl.head(200)
# Out:
#                                                   Lemmas        NctId Ngrams  \
# 149                                     [(Other, other)]  NCT00004399     []
# 610                                     [(Other, other)]  NCT00047073     []
# 636                                     [(Other, other)]  NCT00047073     []
# 959                                     [(Other, other)]  NCT00068770     []
# 993                                     [(Other, other)]  NCT00068770     []
# 2529                                    [(Other, other)]  NCT00245037     []
# 8728                                          [(or, or)]  NCT01222247     []
# 8730                                          [(or, or)]  NCT01222247     []
# 10243                                         [(or, or)]  NCT01478035     []
# 15733                                         [(OR, or)]  NCT02374450     []
# 17148                       [(any, any), (other, other)]  NCT02575924     []
# 162    [(Hematopoietic, hematopoietic), (Not, not), (...  NCT00004403     []
# 163    [(Hepatic, hepatic), (Not, not), (specified, s...  NCT00004403     []
# 241            [(1, 1), (Are, be), (pregnant, pregnant)]  NCT00005925     []
# 322    [(Performing, perform), (below, below), (grade...  NCT00016796     []
# 417    [(must, must), (weigh, weigh), (greater, great...  NCT00034814     []
# 595                 [(18, 18), (and, and), (over, over)]  NCT00047073     []
# 600                     [(Hematopoietic, hematopoietic)]  NCT00047073     []
# 605                                 [(Hepatic, hepatic)]  NCT00047073     []
# 619    [(Not, not), (pregnant, pregnant), (or, or), (...  NCT00047073     []
# 682    [(Severe, severe), (spasticity/pain, spasticit...  NCT00050128     []
# 713    [(Be, be), (willing, willing), (to, to), (be, ...  NCT00050934     []
# 854    [(Pregnant, pregnant), (or, or), (lactating, l...  NCT00057460     []
# 939                   [(Supratentorial, supratentorial)]  NCT00068770     []
# 943                 [(18, 18), (and, and), (over, over)]  NCT00068770     []
# 947                   [(Not, not), (specified, specify)]  NCT00068770     []
# 948                     [(Hematopoietic, hematopoietic)]  NCT00068770     []
# 952                                 [(Hepatic, hepatic)]  NCT00068770     []
# 960    [(Not, not), (pregnant, pregnant), (or, or), (...  NCT00068770     []
# 1138   [(They, they), (are, be), (female, female), (a...  NCT00085683     []
# ...                                                  ...          ...    ...
# 13409                   [(Right, right), (handed, hand)]  NCT01984476     []
# 13420  [(piercing, pierce), (that, that), (can, can),...  NCT01984476     []
# 13460  [(Able, able), (to, to), (speak, speak), (and,...  NCT01992393     []
# 13462  [(Diagnosed, diagnose), (with, with), (epileps...  NCT01992393     []
# 13604  [(Diagnosed, diagnose), (as, a), (epilepsy, ep...  NCT02004340     []
# 13828             [(English-speaking, english-speaking)]  NCT02045511     []
# 13914  [(Does, do), (not, not), (consent, consent), (...  NCT02067819     []
# 13917   [(Aged, aged), (18, 18), (or, or), (older, old)]  NCT02071407     []
# 14175               [(Liver, liver), (failure, failure)]  NCT02113943     []
# 14205             [(English-speaking, english-speaking)]  NCT02122458     []
# 14834  [(Unilaterally, unilaterally), (implanted, imp...  NCT02228148     []
# 14851  [(Clinically, clinically), (evolving, evolve),...  NCT02229123     []
# 15090               [(Liver, liver), (failure, failure)]  NCT02267304     []
# 15292  [(3, 3), (At, at), (least, least), (two, two),...  NCT02308982     []
# 15381                     [(right-handed, right-handed)]  NCT02323256     []
# 15386  [(aged, age), (from, from), (1, 1), (to, to), ...  NCT02323256     []
# 15391  [(Aged, aged), (from, from), (18, 18), (to, to...  NCT02323256     []
# 15453                 [(breast-feeding, breast-feeding)]  NCT02332174     []
# 15489  [(Pregnant, pregnant), (or, or), (breastfeedin...  NCT02334722     []
# 15577  [(Inactive, inactive), (physically, physically...  NCT02355912     []
# 15583  [(inactive, inactive), (physically, physically...  NCT02355912     []
# 15714                   [(Scaphocephaly, scaphocephaly)]  NCT02370901     []
# 15846  [(Subject, subject), (is, be), (pregnant, preg...  NCT02403843     []
# 15900  [(Hemodynamically, hemodynamically), (stable, ...  NCT02409433     []
# 15905  [(Hemodynamically, hemodynamically), (unstable...  NCT02409433     []
# 15907               [(Liver, liver), (failure, failure)]  NCT02409433     []
# 15909                             [(Pregnant, pregnant)]  NCT02409433     []
# 15921         [(Community-dwelling, community-dwelling)]  NCT02412254     []
# 16064                     [(Right-handed, right-handed)]  NCT02441478     []
# 16071                     [(Right-handed, right-handed)]  NCT02441478     []
#
#                                                     Tags  \
# 149                                        [(Other, JJ)]
# 610                                        [(Other, JJ)]
# 636                                        [(Other, JJ)]
# 959                                        [(Other, JJ)]
# 993                                        [(Other, JJ)]
# 2529                                       [(Other, JJ)]
# 8728                                          [(or, CC)]
# 8730                                          [(or, CC)]
# 10243                                         [(or, CC)]
# 15733                                         [(OR, CC)]
# 17148                           [(any, DT), (other, JJ)]
# 162    [(Hematopoietic, JJ), (Not, RB), (specified, V...
# 163         [(Hepatic, JJ), (Not, RB), (specified, VBN)]
# 241                [(1, LS), (Are, VBP), (pregnant, JJ)]
# 322    [(Performing, VBG), (below, IN), (grade-level,...
# 417    [(must, MD), (weigh, VB), (greater, JJR), (tha...
# 595                    [(18, CD), (and, CC), (over, IN)]
# 600                                [(Hematopoietic, JJ)]
# 605                                      [(Hepatic, JJ)]
# 619    [(Not, RB), (pregnant, JJ), (or, CC), (nursing...
# 682                [(Severe, RB), (spasticity/pain, JJ)]
# 713    [(Be, VB), (willing, JJ), (to, TO), (be, VB), ...
# 854         [(Pregnant, JJ), (or, CC), (lactating, VBG)]
# 939                               [(Supratentorial, JJ)]
# 943                    [(18, CD), (and, CC), (over, IN)]
# 947                        [(Not, RB), (specified, VBN)]
# 948                                [(Hematopoietic, JJ)]
# 952                                      [(Hepatic, JJ)]
# 960    [(Not, RB), (pregnant, JJ), (or, CC), (nursing...
# 1138   [(They, PRP), (are, VBP), (female, JJ), (and, ...
# ...                                                  ...
# 13409                       [(Right, RB), (handed, VBD)]
# 13420  [(piercing, VBG), (that, IN), (can, MD), (not,...
# 13460  [(Able, JJ), (to, TO), (speak, VB), (and, CC),...
# 13462     [(Diagnosed, VBN), (with, IN), (epilepsy, JJ)]
# 13604       [(Diagnosed, VBN), (as, IN), (epilepsy, JJ)]
# 13828                           [(English-speaking, JJ)]
# 13914  [(Does, VBZ), (not, RB), (consent, VB), (to, T...
# 13917     [(Aged, JJ), (18, CD), (or, CC), (older, JJR)]
# 14175                      [(Liver, RB), (failure, VBP)]
# 14205                           [(English-speaking, JJ)]
# 14834             [(Unilaterally, RB), (implanted, VBN)]
# 14851  [(Clinically, RB), (evolving, VBG), (encephalo...
# 15090                      [(Liver, RB), (failure, VBP)]
# 15292  [(3, LS), (At, IN), (least, JJS), (two, CD), (...
# 15381                               [(right-handed, JJ)]
# 15386  [(aged, VBD), (from, IN), (1, CD), (to, TO), (...
# 15391  [(Aged, JJ), (from, IN), (18, CD), (to, TO), (...
# 15453                             [(breast-feeding, JJ)]
# 15489   [(Pregnant, JJ), (or, CC), (breastfeeding, VBG)]
# 15577    [(Inactive, JJ), (physically, RB), (unfit, JJ)]
# 15583    [(inactive, JJ), (physically, RB), (unfit, JJ)]
# 15714                              [(Scaphocephaly, RB)]
# 15846         [(Subject, JJ), (is, VBZ), (pregnant, JJ)]
# 15900              [(Hemodynamically, RB), (stable, JJ)]
# 15905            [(Hemodynamically, RB), (unstable, JJ)]
# 15907                      [(Liver, RB), (failure, VBP)]
# 15909                                   [(Pregnant, JJ)]
# 15921                         [(Community-dwelling, JJ)]
# 16064                               [(Right-handed, JJ)]
# 16071                               [(Right-handed, JJ)]
#
#                                                   Tokens
# 149                                              [Other]
# 610                                              [Other]
# 636                                              [Other]
# 959                                              [Other]
# 993                                              [Other]
# 2529                                             [Other]
# 8728                                                [or]
# 8730                                                [or]
# 10243                                               [or]
# 15733                                               [OR]
# 17148                                       [any, other]
# 162                      [Hematopoietic, Not, specified]
# 163                            [Hepatic, Not, specified]
# 241                                   [1, Are, pregnant]
# 322                     [Performing, below, grade-level]
# 417    [must, weigh, greater, than, or, equal, to, 40kg]
# 595                                      [18, and, over]
# 600                                      [Hematopoietic]
# 605                                            [Hepatic]
# 619                         [Not, pregnant, or, nursing]
# 682                            [Severe, spasticity/pain]
# 713                  [Be, willing, to, be, hospitalized]
# 854                            [Pregnant, or, lactating]
# 939                                     [Supratentorial]
# 943                                      [18, and, over]
# 947                                     [Not, specified]
# 948                                      [Hematopoietic]
# 952                                            [Hepatic]
# 960                         [Not, pregnant, or, nursing]
# 1138             [They, are, female, and, are, pregnant]
# ...                                                  ...
# 13409                                    [Right, handed]
# 13420         [piercing, that, can, not, be, taken, out]
# 13460        [Able, to, speak, and, understand, English]
# 13462                        [Diagnosed, with, epilepsy]
# 13604                          [Diagnosed, as, epilepsy]
# 13828                                 [English-speaking]
# 13914        [Does, not, consent, to, being, videotaped]
# 13917                              [Aged, 18, or, older]
# 14175                                   [Liver, failure]
# 14205                                 [English-speaking]
# 14834                          [Unilaterally, implanted]
# 14851             [Clinically, evolving, encephalopathy]
# 15090                                   [Liver, failure]
# 15292                            [3, At, least, two, of]
# 15381                                     [right-handed]
# 15386                            [aged, from, 1, to, 70]
# 15391                           [Aged, from, 18, to, 70]
# 15453                                   [breast-feeding]
# 15489                      [Pregnant, or, breastfeeding]
# 15577                      [Inactive, physically, unfit]
# 15583                      [inactive, physically, unfit]
# 15714                                    [Scaphocephaly]
# 15846                            [Subject, is, pregnant]
# 15900                          [Hemodynamically, stable]
# 15905                        [Hemodynamically, unstable]
# 15907                                   [Liver, failure]
# 15909                                         [Pregnant]
# 15921                               [Community-dwelling]
# 16064                                     [Right-handed]
# 16071                                     [Right-handed]
#
# [200 rows x 5 columns]
