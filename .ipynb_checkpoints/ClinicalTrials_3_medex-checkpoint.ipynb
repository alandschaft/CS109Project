# %% [markdown]
# # Initial setup
#
# Let's import the required libraries and set up global variables for the rest of the script.

# %%
# coding: utf-8
# !pip install tqdm
import csv
import os
import re
import shutil
import string
import zipfile
import sys
from collections import defaultdict
from lxml import objectify
import codecs
import nltk
import pandas as pd
import requests
import tarfile
import subprocess
import platform
import time
from tqdm import tqdm as progressbar # pandas df usage: 'for row in progressbar(df.itertuples(), total=df.shape[0])'

import glob
import numpy as np
# Out:
# Requirement already satisfied (use --upgrade to upgrade): tqdm in /anaconda/lib/python2.7/site-packages

# %% [markdown]
# Helper function to create a directory under the specified path, gracefully handling errors.

# %%
def __mkdir(*args):
    path = os.path.join(*args)
    try: 
        os.makedirs(path)
    except OSError:
        if not os.path.isdir(path):
            raise
    return path

# %%
# Create the project directory holding the downloaded data, serialized dataframes and MetaMap install.
# working_dir = __mkdir(os.path.expanduser("~"), "Medframes")

# Set working directory as the current directory of the ipython notebook
working_dir = os.getcwd()
data_dir = __mkdir(working_dir, "data")
print("Working directory: %s" % working_dir)
# Out:
# Working directory: /Users/Lo/Work/CS109Project

# %% [markdown]
# # Load data for MedEx processing

# %%
# %time
criteria = pd.read_pickle(os.path.join(data_dir, 'ct_filtered.pckl'))
criteria.head()
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
#                                               Lemmas        NctId  \
# 0  [(History, history), (of, of), (uncontrolled, ...  NCT00001149
# 1  [(Seizure, seizure), (frequency, frequency), (...  NCT00001149
# 2  [(Patients, patient), (of, of), (any, any), (a...  NCT00001149
# 3  [(Patients, patient), (and, and), (parents, pa...  NCT00001149
# 4                              [(Patients, patient)]  NCT00001192
#
#                                               Ngrams  \
# 0  [((time, NN),), ((prior, RB), (to, TO), (admis...
# 1  [((frequency, NN), (by, IN)), ((video, NN),), ...
# 2  [((patient, NNS), (of, IN)), ((any, DT), (age,...
# 3  [((express, NN), (willingness, NN), (to, TO)),...
# 4                                [((patient, NNS),)]
#
#                                                 Tags  \
# 0  [(History, NN), (of, IN), (uncontrolled, VBN),...
# 1  [(Seizure, NN), (frequency, NN), (by, IN), (hi...
# 2  [(Patients, NNS), (of, IN), (any, DT), (age, N...
# 3  [(Patients, NNS), (and, CC), (parents, NNS), (...
# 4                                  [(Patients, NNS)]
#
#                                               Tokens  criteria_id
# 0  [History, of, uncontrolled, seizures, at, the,...            0
# 1  [Seizure, frequency, by, history, must, be, su...            1
# 2        [Patients, of, any, age, may, be, accepted]            2
# 3  [Patients, and, parents, or, guardians, if, ap...            3
# 4                                         [Patients]            4

# %% [markdown]
# # MedEx Settings
#
# Please configure MedEx tagging settings here.

# %%
#medex input % output directory

medex_in = working_dir + "/data/medex_in/"
medex_out = working_dir + "/data/medex_out/"

keep_txt_files = True

# %% [markdown]
# # Preprocess the data by creating criteria text files
#
# Create MedEx input files by exporting each criteria to a text file to "medex_in" directory.

# %%
def add_medex_prep(df, medex_in):
    for (cid, row) in zip(criteria.criteria_id, criteria.Lemmas):
        f = open(medex_in + "medex_" + str(cid) + ".txt", "w")
        #for word in row:
        for word in [k[1] for k in row]:
            f.write(word.encode('ascii', 'replace') + u' ')
        f.close()

add_medex_prep(criteria, medex_in)

# %% [markdown]
# # Process the data with MedEx
#
# At this moment MedEx is ran in the system shell outside of the notebook.
#
# Command Format (in MedEx installation folder):
#
# $ java -Xmx1024m -cp lib/*:bin org.apache.medex.Main -i [input directory] -o [output directory]
#
# eg.) $ java -Xmx1024m -cp lib/*:bin org.apache.medex.Main -i '/Users/Lo/Work/cs109project/data/medex_in/' -o '/Users/Lo/Work/cs109project/data/medex_out/'
#
# MedEx scans all text files in the input directory and export the NLP results of each file to the output directory in this format:
# {sentence order}-{sentence}
# {

# %% [markdown]
# # Parse MedEx data and write to criteria dataframe

# %%
#parse medex output results, add column, delete the generated txt files
def create_medex_df(df, medex_in, medex_out, keeptxt=keep_txt_files):
    
    #remove empty output files
    for dirpath, dirs, files in os.walk(medex_out):
        for file in files: 
            path = os.path.join(dirpath, file)
            if os.stat(path).st_size == 0:
                os.remove(path)
                
    #read raw data in txt files
    cid_list = []
    raw_drug_data = []
    for file in glob.glob(medex_out + "*.txt"):
        cid_list.append(int(file.split('/')[-1][6:-4])) # file # = criteria id
        
        with open (file, "r") as raw:
            raw_drug_data.append(raw.read().rstrip('\n'))
            
    #delete all files under the input and output directories 
    if not keeptxt:
        files = glob.glob(medex_out+'*') + glob.glob(medex_in+'*')
        for f in files:
            os.remove(f)
    
    """
    #parse raw drug data
    processed_drug_data = []
    for i in range(len(raw_drug_data)):
        
        processed = [[re.sub(r'\[.+?\]\s*', '', i.split('|')[1]), i.split('|')[-1]] for i in raw_drug_data[i].split('\n')]
        # medex identify refusal as a drug. Remove these results.
        # may need to look at other ones
        #if "refusal" in [col.lower() for col in processed]:
        #    rowlist.remove(rowlist[i])
        #else:
        #    processed_drug_data.append(processed)
        processed_drug_data.append(processed)
            
    #create MedEx column and add parsed medex data to df
    df['MedEx']=''
    for (count, i) in enumerate(rowlist):
        df.MedEx[i] = processed_drug_data[count]
    """
            
    processed = []
    for (count, i) in enumerate(raw_drug_data):
        for k in i.split('\n'):
            v = [re.sub(r'\[.+?\]\s*', '', j) for j in k.split('|')[1:]]
            v.append(cid_list[count])
            processed.append(v)
    medex_df = pd.DataFrame(processed, columns=['drug_name', 'brand_name', 'drug_form', 'strength', 'dose',
                                                'route', 'frequency', 'duration', 'neccessity', 'cui',
                                                'rxnorm_cui', 'rxnorm_cui_generic', 'generic_name','criteria_id'])
    medex_df = pd.merge(df.loc[:, ['NctId', 'criteria_id']], medex_df, on='criteria_id', how='right')
    medex_df = medex_df.rename(columns={'NctId': 'nct_id'})
    
    return medex_df
    
added = create_medex_df(criteria.loc[:, ['NctId', 'criteria_id']], medex_in, medex_out)
added.to_pickle(os.path.join(data_dir, 'medex.pckl'))

added.head(100)
# Out:
#           NctId  criteria_id            drug_name brand_name drug_form  \
# 0   NCT00001205            8      corticosteroids
# 1   NCT00001205            8   immunosuppressives
# 2   NCT00001205           11         praziquantel
# 3   NCT00001205           11          albendazole
# 4   NCT00001205           11         methotrexate
# 5   NCT00001205           11      corticosteroids
# 6   NCT00001205           11           etanercept
# 7   NCT00001205           14        anthelmintics
# 8   NCT00001205           14      corticosteroids
# 9   NCT00001205           14   immunosuppressives
# 10  NCT00001205           15        anthelmintics
# 11  NCT00001205           15    immunosuppressive
# 12  NCT00001205           16          albendazole
# 13  NCT00001205           16         praziquantel
# 14  NCT00001289           29              refusal
# 15  NCT00001404           42                  MPA
# 16  NCT00001489           47             tegretol
# 17  NCT00001489           49           vigabatrin
# 18  NCT00001666           52           convulsant
# 19  NCT00001666           52          convulsants
# 20  NCT00001666           53           convulsant
# 21  NCT00001666           62          neuroleptic
# 22  NCT00001666           62       antidepressant
# 23  NCT00001725           73             Norplant
# 24  NCT00001725           73  oral contraceptives
# 25  NCT00001725           81           topiramate
# 26  NCT00001725           81     dextromethorphan
# 27  NCT00001725           84    experimental drug
# 28  NCT00001726           87    immunosuppressant
# 29  NCT00001932          108        antiepileptic
# ..          ...          ...                  ...        ...       ...
# 70  NCT00011063          301           analgesics
# 71  NCT00015769          310        carbamazepine
# 72  NCT00015769          310            valproate
# 73  NCT00015769          310              lithium
# 74  NCT00015769          310        levetiracetam
# 75  NCT00015769          310         neuroleptics
# 76  NCT00021866          325            phenytoin
# 77  NCT00021866          325          lamotrigine
# 78  NCT00021866          325        carbamazepine
# 79  NCT00021866          325            valproate
# 80  NCT00021866          332        prenatal care
# 81  NCT00025987          336     herbal medicines
# 82  NCT00026637          357           sertraline
# 83  NCT00026637          359       antidepressant
# 84  NCT00027209          383    experimental drug
# 85  NCT00027209          386              Prempro
# 86  NCT00028262          391             Cystagon
# 87  NCT00028262          391             Cystagon
# 88  NCT00028262          391             Cystagon
# 89  NCT00028262          395        antiepileptic
# 90  NCT00029536          401        antiepileptic
# 91  NCT00029536          405       antidepressant
# 92  NCT00029536          405  major tranquilizers
# 93  NCT00034814          422        Valproic acid
# 94  NCT00034814          422            Felbamate
# 95  NCT00040326          435            Carbatrol
# 96  NCT00040326          435             Tegretol
# 97  NCT00040326          435             Dilantin
# 98  NCT00040326          435            Trileptal
# 99  NCT00040326          438  febrile convulsions
#
#    strength dose   route frequency       duration neccessity       cui  \
# 0                                                             C0001617
# 1                                   2 to 75 years
# 2                                                             C0032911
# 3                                                             C0001911
# 4                                                             C0025677
# 5                                                             C0001617
# 6                                                             C0717758
# 7                                                             C0003158
# 8                                                             C0001617
# 9
# 10                                                            C0003158
# 11
# 12                                                            C0001911
# 13                                                            C0032911
# 14
# 15
# 16
# 17                                                            C0048044
# 18
# 19
# 20                        per week       6 months
# 21
# 22
# 23
# 24
# 25                                                            C0076829
# 26                                                            C0011816
# 27                                        30 days
# 28
# 29                                                            C0003299
# ..      ...  ...     ...       ...            ...        ...       ...
# 70                                        2 weeks             C0002771
# 71                                                            C0006949
# 72                                                            C0080356
# 73                                                            C0023870
# 74                                                            C0377265
# 75
# 76                                                            C0031507
# 77                                                            C0064636
# 78                                                            C0006949
# 79                                                            C0080356
# 80
# 81
# 82                                                            C0074393
# 83
# 84                                        30 days
# 85                                                            C0722753
# 86                                                            C0733368
# 87                                                            C0733368
# 88                                                            C0733368
# 89                orally                 6 months             C0003299
# 90                                       2 months             C0003299
# 91
# 92
# 93                                                            C0042291
# 94                                                            C0060135
# 95                                                            C0719149
# 96
# 97
# 98                                                            C1452042
# 99
#
#    rxnorm_cui rxnorm_cui_generic          generic_name
# 0         354                354       corticosteroids
# 1
# 2        8628               8628          praziquantel
# 3         430                430           albendazole
# 4        6851               6851          methotrexate
# 5         354                354       corticosteroids
# 6      214555             214555            etanercept
# 7         868                868         anthelmintics
# 8         354                354       corticosteroids
# 9
# 10        868                868         anthelmintics
# 11       5748               5748     immunosuppressive
# 12        430                430           albendazole
# 13       8628               8628          praziquantel
# 14
# 15
# 16     203029               2002         carbamazepine
# 17      14851              14851            vigabatrin
# 18
# 19
# 20
# 21      10693              10693    antipsychotic drug
# 22        927                927        antidepressant
# 23     342998               6373        levonorgestrel
# 24       2821               2821   oral contraceptives
# 25      38404              38404            topiramate
# 26       3289               3289      dextromethorphan
# 27      91034              91034     experimental drug
# 28       5748               5748     immunosuppressant
# 29        932                932         antiepileptic
# ..        ...                ...                   ...
# 70        760                760            analgesics
# 71       2002               2002         carbamazepine
# 72      40254              40254             valproate
# 73       6448               6448               lithium
# 74     114477             114477         levetiracetam
# 75
# 76       8183               8183             phenytoin
# 77      28439              28439           lamotrigine
# 78       2002               2002         carbamazepine
# 79      40254              40254             valproate
# 80     219367             219367         prenatal care
# 81     817354             817354      herbal medicines
# 82      36437              36437            sertraline
# 83        927                927        antidepressant
# 84      91034              91034     experimental drug
# 85     219362               4099  conjugated estrogens
# 86     227215               3022          mercaptamine
# 87     227215               3022          mercaptamine
# 88     227215               3022          mercaptamine
# 89        932                932         antiepileptic
# 90        932                932         antiepileptic
# 91        927                927        antidepressant
# 92     218186             218186   major tranquilizers
# 93      11118              11118         valproic acid
# 94      24812              24812             felbamate
# 95     215879               2002         carbamazepine
# 96     203029               2002         carbamazepine
# 97     202740               8183             phenytoin
# 98     261680              32624         oxcarbazepine
# 99    1023313            1023313   febrile convulsions
#
# [100 rows x 15 columns]

# %%
# rules:
# remove refusal
# replace " - " with "-"
# some similar ones: ['neuroleptic', 'antipsychotic drug'] and ['neuroleptic drugs', 'antipsychotic drug']
